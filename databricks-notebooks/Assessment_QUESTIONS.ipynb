# %% [markdown]
# # DE Bootcamp - Core Assessment (Notebooks 1-5)
#
# **70 questions** - 10 concept questions on Data Engineering foundations, then **60 hands-on coding questions** across SQL, Python, pandas, and PySpark. Hints are given; answers are in **Assessment_ANSWERS.ipynb**.
#
# ---

# %% [markdown]
# # >>> STEP 1: RUN THIS CELL FIRST <<<
#
# `%run` executes the setup notebook **in this same session**, creating all the tables and DataFrames the coding questions use. This is what makes two separate notebooks work on **serverless**.
#
# - `Assessment_SETUP` must be in the **same workspace folder** as this notebook.
# - The `%run` line must be the **only** thing in its cell.
# - Re-run this if your session restarts.
#
# Gives you `employees`, `sales`, `orders`, `customers` (SQL views + Spark DataFrames) and Spark `df`.

# %%
# %run ./Assessment_SETUP

# %% [markdown]
# ### Before the pandas section (Q36-Q50), run this cell
# It switches `df`, `orders`, `customers` to the pandas versions. To go back to Spark for the PySpark section, re-run the `%run` cell above.

# %%
df, orders, customers = df_pd, orders_pd.copy(), customers_pd.copy()
df.head()

# %% [markdown]
# ---

# %% [markdown]
# # Data Engineering Introduction  (10 questions)
#
# *Concept questions - write your answer in prose*

# %% [markdown]
# ### Q1. Explain the difference between OLTP and OLAP. Give one example of each and the workload each is optimized for.
#
# > **Hint:** 'Runs the business' vs 'understands the business' - many small transactions vs large analytical scans.

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q2. Why is columnar storage preferred for analytical (OLAP) workloads compared with row storage?
#
# > **Hint:** Analytics reads a few columns across millions of rows; which layout reads less and compresses better?

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q3. Compare a Data Warehouse and a Data Lake - what does each store, and what is the key trade-off?
#
# > **Hint:** Organized library (schema-on-write, structured, costly) vs giant reservoir (schema-on-read, any format, cheap).

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q4. What is a Lakehouse and which technology enables it on top of Parquet files?
#
# > **Hint:** Warehouse reliability on lake-cheap storage; think Delta Lake and a transaction log.

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q5. Explain the difference between a fact table and a dimension table.
#
# > **Hint:** Numbers you measure vs descriptive context you filter/group by.

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q6. Describe a star schema vs a snowflake schema, and one trade-off of snowflaking.
#
# > **Hint:** Central fact + denormalized dims vs dims split into sub-tables.

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q7. What is the difference between ETL and ELT, and why has ELT become popular in the cloud?
#
# > **Hint:** Where does the transform happen - before load, or after load inside a powerful platform?

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q8. Explain the Medallion Architecture and the purpose of the Bronze, Silver, and Gold layers.
#
# > **Hint:** Raw -> cleaned/conformed -> business-ready aggregates.

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q9. What is Apache Spark and why is it well suited to big data? Mention distributed computing.
#
# > **Hint:** An engine that splits work across a cluster and processes in memory.

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ### Q10. What does ACID stand for, and why does it matter for a lakehouse table?
#
# > **Hint:** Atomicity, Consistency, Isolation, Durability - reliable transactions despite concurrency/failures.

# %% [markdown]
# **Your answer:**
#
# *(write your response here)*

# %% [markdown]
# ---

# %% [markdown]
# # SQL  (15 questions)
#
# *Practical - write SQL. Tip: start the cell with %sql, or use spark.sql(""" ... """).*

# %% [markdown]
# ### Q11. Return the distinct department names from `employees`, sorted A-Z.
#
# > **Hint:** DISTINCT + ORDER BY.

# %%
# %sql
-- Q11: write your SQL below

# %% [markdown]
# ### Q12. From `employees`, return name and salary for people in 'NYC' earning more than 60000, highest salary first.
#
# > **Hint:** WHERE with AND; ORDER BY ... DESC.

# %%
# %sql
-- Q12: write your SQL below

# %% [markdown]
# ### Q13. Count how many employees are in each department.
#
# > **Hint:** GROUP BY department, COUNT(*).

# %%
# %sql
-- Q13: write your SQL below

# %% [markdown]
# ### Q14. Return each department and its average salary, but only departments whose average salary exceeds 60000.
#
# > **Hint:** GROUP BY then filter groups with HAVING.

# %%
# %sql
-- Q14: write your SQL below

# %% [markdown]
# ### Q15. Return the 3 highest-paid employees (name, salary).
#
# > **Hint:** ORDER BY salary DESC then LIMIT.

# %%
# %sql
-- Q15: write your SQL below

# %% [markdown]
# ### Q16. Join `orders` to `customers` and return order_id, customer_name, and order_date (matches only).
#
# > **Hint:** INNER JOIN on customer_id.

# %%
# %sql
-- Q16: write your SQL below

# %% [markdown]
# ### Q17. List the customers (customer_name) who have never placed an order.
#
# > **Hint:** Anti-join: LEFT ANTI JOIN, or NOT IN / NOT EXISTS.

# %%
# %sql
-- Q17: write your SQL below

# %% [markdown]
# ### Q18. Return each customer_name and their total sales amount (join sales to customers), largest total first.
#
# > **Hint:** JOIN sales+customers, GROUP BY, SUM, ORDER BY DESC.

# %%
# %sql
-- Q18: write your SQL below

# %% [markdown]
# ### Q19. Using a CTE, compute total sales per customer_id, then return only those with total above 1000.
#
# > **Hint:** WITH t AS (...) SELECT ... WHERE total > 1000.

# %%
# %sql
-- Q19: write your SQL below

# %% [markdown]
# ### Q20. Rank employees by salary within each department (highest = 1) using a window function; return name, department, salary, rank.
#
# > **Hint:** ROW_NUMBER() OVER (PARTITION BY department ORDER BY salary DESC).

# %%
# %sql
-- Q20: write your SQL below

# %% [markdown]
# ### Q21. For each employee, show their salary alongside their department's average salary in the same row.
#
# > **Hint:** AVG(salary) OVER (PARTITION BY department).

# %%
# %sql
-- Q21: write your SQL below

# %% [markdown]
# ### Q22. For each customer's orders ordered by date, show the previous order_date (NULL for the first).
#
# > **Hint:** LAG(order_date) OVER (PARTITION BY customer_id ORDER BY order_date).

# %%
# %sql
-- Q22: write your SQL below

# %% [markdown]
# ### Q23. Add a salary_band column: 'High' if salary > 80000, 'Medium' if 50000-80000, else 'Low'.
#
# > **Hint:** CASE WHEN ... THEN ... ELSE ... END.

# %%
# %sql
-- Q23: write your SQL below

# %% [markdown]
# ### Q24. From `orders`, return the year and month of each order_date and count how many orders fall in each month.
#
# > **Hint:** YEAR()/MONTH() (or date_format), then GROUP BY.

# %%
# %sql
-- Q24: write your SQL below

# %% [markdown]
# ### Q25. The `df` view has an array column `items`. Explode it so each item becomes its own row alongside the employee name.
#
# > **Hint:** LATERAL VIEW explode(...) or explode() in SELECT.

# %%
# %sql
-- Q25: write your SQL below

# %% [markdown]
# ---

# %% [markdown]
# # Python  (15 questions)
#
# *Practical - write Python.*

# %% [markdown]
# ### Q26. Count the occurrences of each word in words = ['a','b','a','c','b','a'] and print the result.
#
# > **Hint:** .get(k,0)+1, or collections.Counter.

# %%
# Q26 - write your answer below

# %% [markdown]
# ### Q27. Build a list of the squares of the even numbers from 0 to 9 using a list comprehension.
#
# > **Hint:** [x**2 for x in range(10) if x % 2 == 0].

# %%
# Q27 - write your answer below

# %% [markdown]
# ### Q28. Sort pairs = [(1,'b'), (2,'a'), (3,'c')] by the second element using a lambda.
#
# > **Hint:** sorted(pairs, key=lambda x: x[1]).

# %%
# Q28 - write your answer below

# %% [markdown]
# ### Q29. Write a function total(*nums) that returns the sum of any number of arguments. Test it with total(1,2,3,4).
#
# > **Hint:** *args collects extras into a tuple.

# %%
# Q29 - write your answer below

# %% [markdown]
# ### Q30. Given prices = {'a': 5, 'b': 12, 'c': 8}, build a new dict of only the items priced above 6 using a dict comprehension.
#
# > **Hint:** {k: v for k, v in d.items() if v > 6}.

# %%
# Q30 - write your answer below

# %% [markdown]
# ### Q31. Write a decorator `announce` that prints 'start' before and 'end' after the wrapped function runs, then apply it to a greet() function.
#
# > **Hint:** def announce(fn): def wrapper(*a, **k): ... return wrapper.

# %%
# Q31 - write your answer below

# %% [markdown]
# ### Q32. Write a generator function fib(n) that yields the first n Fibonacci numbers, and print list(fib(8)).
#
# > **Hint:** yield inside a loop; keep two running values.

# %%
# Q32 - write your answer below

# %% [markdown]
# ### Q33. Define a Dog class with a name attribute and a bark() method returning '<name> says woof'. Create one and call bark().
#
# > **Hint:** __init__(self, name); self.name; return f-string.

# %%
# Q33 - write your answer below

# %% [markdown]
# ### Q34. Given values = ['10', 'x', '20', 'bad', '5'], build a list of the ones that convert to int, skipping the rest (use try/except).
#
# > **Hint:** Loop, try int(v), except ValueError: continue.

# %%
# Q34 - write your answer below

# %% [markdown]
# ### Q35. Use a `with` block to write 'hello world' to /tmp/demo.txt, then read it back and print it.
#
# > **Hint:** with open(path,'w') as f: ... ; with open(path) as f: f.read().

# %%
# Q35 - write your answer below

# %% [markdown]
# ### Q36. Given pairs = [('eng','Alice'), ('sales','Bob'), ('eng','Grace')], group names by department into a dict {dept: [names]}.
#
# > **Hint:** collections.defaultdict(list) then append.

# %%
# Q36 - write your answer below

# %% [markdown]
# ### Q37. Flatten nested = [[1, 2], [3, 4], [5]] into a single flat list using a comprehension.
#
# > **Hint:** [x for sub in nested for x in sub].

# %%
# Q37 - write your answer below

# %% [markdown]
# ### Q38. Use a regular expression to extract all numbers from the string 'order 12 has 3 items and 45 units' as a list of ints.
#
# > **Hint:** re.findall(r'\d+', s) then map to int.

# %%
# Q38 - write your answer below

# %% [markdown]
# ### Q39. Format price = 1234.5 as the string 'Total: $1,234.50' using an f-string.
#
# > **Hint:** f'{price:,.2f}' adds thousands separator and 2 decimals.

# %%
# Q39 - write your answer below

# %% [markdown]
# ### Q40. Count the vowels in the string 'data engineering' and print the count.
#
# > **Hint:** sum(1 for ch in s if ch in 'aeiou').

# %%
# Q40 - write your answer below

# %% [markdown]
# ---

# %% [markdown]
# # pandas  (15 questions)
#
# *Practical - pandas (run the pandas activation cell first).*

# %% [markdown]
# ### Q41. Show the shape, column dtypes, and summary statistics (describe) of the pandas `df`.
#
# > **Hint:** df.shape, df.dtypes, df.describe().

# %%
# Q41 - write your answer below

# %% [markdown]
# ### Q42. Filter `df` to rows where age > 30 AND city == 'NYC'.
#
# > **Hint:** Boolean masks with & and parentheses.

# %%
# Q42 - write your answer below

# %% [markdown]
# ### Q43. Add a new column `bonus` equal to 10% of salary (vectorized).
#
# > **Hint:** df['bonus'] = df['salary'] * 0.10.

# %%
# Q43 - write your answer below

# %% [markdown]
# ### Q44. `df` has missing values. Fill missing salary with the column mean and fill missing city with 'Unknown'.
#
# > **Hint:** df['salary'].fillna(df['salary'].mean()); df['city'].fillna('Unknown').

# %%
# Q44 - write your answer below

# %% [markdown]
# ### Q45. Compute the average salary per department.
#
# > **Hint:** df.groupby('department')['salary'].mean().

# %%
# Q45 - write your answer below

# %% [markdown]
# ### Q46. For each department, compute the mean, count, and max of salary in one call.
#
# > **Hint:** groupby(...)['salary'].agg(['mean','count','max']).

# %%
# Q46 - write your answer below

# %% [markdown]
# ### Q47. Return the 5 highest-paid rows, sorted by salary descending (name and salary).
#
# > **Hint:** df.sort_values('salary', ascending=False).head(5).

# %%
# Q47 - write your answer below

# %% [markdown]
# ### Q48. Using .loc, select the name and salary columns for all Engineering employees.
#
# > **Hint:** df.loc[mask, ['name','salary']].

# %%
# Q48 - write your answer below

# %% [markdown]
# ### Q49. Merge `orders` and `customers` on customer_id with an inner join.
#
# > **Hint:** pd.merge(orders, customers, on='customer_id', how='inner').

# %%
# Q49 - write your answer below

# %% [markdown]
# ### Q50. Count how many employees are in each city (a frequency count).
#
# > **Hint:** df['city'].value_counts().

# %%
# Q50 - write your answer below

# %% [markdown]
# ### Q51. Create a column `name_upper` with the uppercased name, and filter to rows whose name contains the letter 'a'.
#
# > **Hint:** df['name'].str.upper(); df['name'].str.contains('a', case=False).

# %%
# Q51 - write your answer below

# %% [markdown]
# ### Q52. From the order_date column, extract the year and month into new columns.
#
# > **Hint:** df['order_date'].dt.year and .dt.month.

# %%
# Q52 - write your answer below

# %% [markdown]
# ### Q53. Build a pivot_table of the average salary by department.
#
# > **Hint:** pd.pivot_table(df, values='salary', index='department', aggfunc='mean').

# %%
# Q53 - write your answer below

# %% [markdown]
# ### Q54. Add a `salary_band` column ('High' >80000, 'Medium' 50000-80000, else 'Low') using apply with a function or lambda.
#
# > **Hint:** df['salary'].apply(lambda s: ...).

# %%
# Q54 - write your answer below

# %% [markdown]
# ### Q55. Write `df` to /tmp/emp.csv without the index, then read it back into a new DataFrame and show head().
#
# > **Hint:** df.to_csv(path, index=False); pd.read_csv(path).

# %%
# Q55 - write your answer below

# %% [markdown]
# ---

# %% [markdown]
# # PySpark  (15 questions)
#
# *Practical - PySpark (make sure the %run cell has been run so Spark df exists).*

# %% [markdown]
# ### Q56. From Spark `df`, select name and age and keep only rows where age > 30.
#
# > **Hint:** df.select(...).filter(col('age') > 30).

# %%
# Q56 - write your answer below

# %% [markdown]
# ### Q57. Add a column `age_plus_10` equal to age + 10.
#
# > **Hint:** withColumn('age_plus_10', col('age') + 10).

# %%
# Q57 - write your answer below

# %% [markdown]
# ### Q58. Group `df` by department and compute the average salary, aliased as avg_salary.
#
# > **Hint:** groupBy('department').agg(avg('salary').alias('avg_salary')).

# %%
# Q58 - write your answer below

# %% [markdown]
# ### Q59. Count how many employees are in each city.
#
# > **Hint:** groupBy('city').count().

# %%
# Q59 - write your answer below

# %% [markdown]
# ### Q60. Return the 5 highest-paid rows (name, salary), highest first.
#
# > **Hint:** orderBy(col('salary').desc()) then limit/show(5).

# %%
# Q60 - write your answer below

# %% [markdown]
# ### Q61. Inner-join `orders` and `customers` on customer_id and show order_id and customer_name.
#
# > **Hint:** orders.join(customers, on='customer_id', how='inner').

# %%
# Q61 - write your answer below

# %% [markdown]
# ### Q62. Find customers who never placed an order using a left anti join.
#
# > **Hint:** customers.join(orders, on='customer_id', how='left_anti').

# %%
# Q62 - write your answer below

# %% [markdown]
# ### Q63. Rank employees by salary within each department (highest = 1) using a window function.
#
# > **Hint:** Window.partitionBy('department').orderBy(col('salary').desc()); row_number().over(w).

# %%
# Q63 - write your answer below

# %% [markdown]
# ### Q64. Add a column `dept_avg` that is the average salary of each row's department (window aggregate, no collapsing rows).
#
# > **Hint:** avg('salary').over(Window.partitionBy('department')).

# %%
# Q64 - write your answer below

# %% [markdown]
# ### Q65. Add a `salary_band` column ('High' >80000, 'Medium' 50000-80000, else 'Low') using when/otherwise.
#
# > **Hint:** F.when(cond, val).when(...).otherwise(...).

# %%
# Q65 - write your answer below

# %% [markdown]
# ### Q66. Create a small DataFrame that contains a null, then fill the nulls in its 'score' column with 0.
#
# > **Hint:** df.na.fill(0, subset=['score']) or fillna.

# %%
# Q66 - write your answer below

# %% [markdown]
# ### Q67. Add two columns to `df`: name in uppercase and the length of name.
#
# > **Hint:** F.upper(col('name')), F.length(col('name')).

# %%
# Q67 - write your answer below

# %% [markdown]
# ### Q68. From `orders`, convert order_date to a date type and extract the year and month into columns.
#
# > **Hint:** to_date, year(), month().

# %%
# Q68 - write your answer below

# %% [markdown]
# ### Q69. `df` has an array column `items`. Explode it so each element becomes its own row next to name.
#
# > **Hint:** F.explode('items') inside withColumn/select.

# %%
# Q69 - write your answer below

# %% [markdown]
# ### Q70. Register `df` as a temp view and use spark.sql to get the average salary per department.
#
# > **Hint:** createOrReplaceTempView then spark.sql('SELECT ... GROUP BY ...').

# %%
# Q70 - write your answer below

# %% [markdown]
# ---

# %% [markdown]
# ## Done!
#
# Check yourself against **Assessment_ANSWERS.ipynb** and score out of 70.
