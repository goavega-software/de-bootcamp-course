# %% [markdown]
# # 02 · Filtering Rows with `WHERE`
#
# `WHERE` keeps only the rows that match a condition. This module covers:
# - comparison operators (`=`, `<>`, `<`, `>`, `<=`, `>=`)
# - combining conditions with `AND`, `OR`, `NOT`
# - `BETWEEN`, `IN`
# - pattern matching with `LIKE`
# - handling `NULL` with `IS NULL` / `IS NOT NULL`

# %%
# ▶ Run this cell first. It loads JupySQL and connects to the SQLite database.
# %load_ext sql
from sqlalchemy import create_engine
import os

# Works whether the notebook's working dir is the repo root or notebooks/
db_path = 'data/retail.db' if os.path.exists('data/retail.db') else '../data/retail.db'
engine = create_engine(f'sqlite:///{db_path}')

# %config SqlMagic.autopandas = True      # results come back as pandas DataFrames
# %config SqlMagic.displaycon = False
# %config SqlMagic.feedback = 0
# %config SqlMagic.displaylimit = 100

# %sql engine
print('Connected to', db_path)

# %% [markdown]
# ## Simple comparison
# Products that cost more than $50:

# %%
# %%sql
# SELECT product_name, unit_price FROM products WHERE unit_price > 50;

# %% [markdown]
# ## Equality and not-equal
# `<>` (or `!=`) means "not equal".

# %%
# %%sql
# SELECT order_id, status FROM orders WHERE status <> 'completed';

# %% [markdown]
# ## Combining with `AND` / `OR`
# Electronics (category 1) under $100:

# %%
# %%sql
# SELECT product_name, unit_price
# FROM products
# WHERE category_id = 1 AND unit_price < 100;

# %% [markdown]
# ## `BETWEEN` (inclusive range)

# %%
# %%sql
# SELECT product_name, unit_price
# FROM products
# WHERE unit_price BETWEEN 30 AND 60;

# %% [markdown]
# ## `IN` (match any of a list)

# %%
# %%sql
# SELECT first_name, country
# FROM customers
# WHERE country IN ('USA', 'UK', 'Japan');

# %% [markdown]
# ## `LIKE` (pattern matching)
# - `%` matches any sequence of characters
# - `_` matches exactly one character
#
# Products whose name contains the word "Pro":

# %%
# %%sql
# SELECT product_name FROM products WHERE product_name LIKE '%Pro%';

# %% [markdown]
# Customers whose first name starts with a letter A–E is hard to do with LIKE alone, but names starting with 'A':

# %%
# %%sql
# SELECT first_name, last_name FROM customers WHERE first_name LIKE 'A%';

# %% [markdown]
# ## Working with `NULL`
# `NULL` means "unknown / missing". You **cannot** use `= NULL`; use `IS NULL`.
# Customer 9 has no email:

# %%
# %%sql
# SELECT customer_id, first_name, email FROM customers WHERE email IS NULL;

# %%
# %%sql
# SELECT customer_id, first_name FROM customers WHERE email IS NOT NULL LIMIT 5;

# %% [markdown]
# ## Practice

# %% [markdown]
# **✏️ Exercise 1.** Find all products with `in_stock` greater than 100.
#
# Try it yourself in the practice cell, then run the solution to check.

# %%
# %%sql
# -- Your turn! Replace the line below with your own query.
# SELECT 'edit me, then run' AS your_answer;

# %% [markdown]
# <details><summary>💡 Show solution</summary>
#
# Run the next cell to see one correct answer.</details>

# %%
# %%sql
# SELECT product_name, in_stock FROM products WHERE in_stock > 100;

# %% [markdown]
# **✏️ Exercise 2.** Find orders that are NOT completed (status is 'pending' or 'cancelled') using the `IN` operator.
#
# Try it yourself in the practice cell, then run the solution to check.

# %%
# %%sql
# -- Your turn! Replace the line below with your own query.
# SELECT 'edit me, then run' AS your_answer;

# %% [markdown]
# <details><summary>💡 Show solution</summary>
#
# Run the next cell to see one correct answer.</details>

# %%
# %%sql
# SELECT order_id, status FROM orders WHERE status IN ('pending', 'cancelled');

# %% [markdown]
# **✏️ Exercise 3.** List products whose name ends with the word "Set".
#
# Try it yourself in the practice cell, then run the solution to check.

# %%
# %%sql
# -- Your turn! Replace the line below with your own query.
# SELECT 'edit me, then run' AS your_answer;

# %% [markdown]
# <details><summary>💡 Show solution</summary>
#
# Run the next cell to see one correct answer.</details>

# %%
# %%sql
# SELECT product_name FROM products WHERE product_name LIKE '%Set';

# %% [markdown]
# **✏️ Exercise 4.** Find customers based in the USA who signed up in 2023 (hint: signup_date is text like '2023-...').
#
# Try it yourself in the practice cell, then run the solution to check.

# %%
# %%sql
# -- Your turn! Replace the line below with your own query.
# SELECT 'edit me, then run' AS your_answer;

# %% [markdown]
# <details><summary>💡 Show solution</summary>
#
# Run the next cell to see one correct answer.</details>

# %%
# %%sql
# SELECT first_name, last_name, signup_date
# FROM customers
# WHERE country = 'USA' AND signup_date LIKE '2023-%';

# %% [markdown]
# ### ✅ Recap
# `WHERE` filters rows; combine conditions with `AND`/`OR`/`NOT`, use ranges with
# `BETWEEN`, lists with `IN`, patterns with `LIKE`, and always test missing values
# with `IS NULL`.
#
# **Next:** `03_sorting_and_limiting.ipynb`.
